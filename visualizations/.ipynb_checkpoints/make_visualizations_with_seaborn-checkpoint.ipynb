# %% [markdown]
# # Visualizing the MT with Seaborn

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# I have made a very simple query:
#
# ```
# clause
#   word lex* g_cons* vt* vs* sp* nu* gn* ps* language*
# ```
#
# I ran this query in the TF Browser app and exported the results. You can find the resulting file in this folder: the_whole_mt.tsv.
# Let's import the dataset in Python with Pandas.

# %%
mt = pd.read_csv('the_whole_mt.tsv', encoding='utf16', sep='\t')

# %% [markdown]
# How many rows and columns does the dataset have?

# %%
mt.shape
# Out:
# (426590, 19)

# %% [markdown]
# Inspect the first 5 rows.

# %%
mt.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis   1   1  427559  clause
# 1  2  Genesis   1   1  427559  clause
# 2  3  Genesis   1   1  427559  clause
# 3  4  Genesis   1   1  427559  clause
# 4  5  Genesis   1   1  427559  clause
#
#                                                TEXT1  NODE2 TYPE2       TEXT2  \
# 0  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...      1  word         בְּ
# 1  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...      2  word  רֵאשִׁ֖ית
# 2  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...      3  word    בָּרָ֣א
# 3  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...      4  word  אֱלֹהִ֑ים
# 4  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...      5  word       אֵ֥ת
#
#   g_cons2  gn2 language2    lex2  nu2  ps2   sp2  vs2   vt2
# 0       B  NaN    Hebrew       B  NaN  NaN  prep  NaN   NaN
# 1   R>CJT    f    Hebrew  R>CJT/   sg  NaN  subs  NaN   NaN
# 2     BR>    m    Hebrew    BR>[   sg   p3  verb  qal  perf
# 3   >LHJM    m    Hebrew  >LHJM/   pl  NaN  subs  NaN   NaN
# 4      >T  NaN    Hebrew      >T  NaN  NaN  prep  NaN   NaN

# %%
book_order = mt.S1.unique()
mt['S1'] = pd.Categorical(mt['S1'], categories=book_order, ordered=True)

# %% [markdown]
# ## How many words are there in each book: barplot.

# %%
word_counts = mt['S1'].value_counts(sort=False)

# %%
word_counts
# Out:
# S1
# Genesis          28764
# Exodus           23748
# Leviticus        17099
# Numbers          23188
# Deuteronomy      20128
# Joshua           14526
# Judges           14086
# 1_Samuel         18929
# 2_Samuel         15612
# 1_Kings          18685
# 2_Kings          17307
# Isaiah           22931
# Jeremiah         29736
# Ezekiel          26182
# Hosea             3146
# Joel              1318
# Amos              2780
# Obadiah            392
# Jonah              985
# Micah             1895
# Nahum              746
# Habakkuk           897
# Zephaniah         1037
# Haggai             877
# Zechariah         4471
# Malachi           1187
# Psalms           25372
# Job              10912
# Proverbs          8859
# Ruth              1802
# Song_of_songs     1682
# Ecclesiastes      4233
# Lamentations      1945
# Esther            4621
# Daniel            8072
# Ezra              5268
# Nehemiah          7842
# 1_Chronicles     15566
# 2_Chronicles     19764
# Name: count, dtype: int64

# %%
ax = sns.barplot(x=word_counts.index, 
                 y=word_counts, 
                 #hue=word_counts.index,
                 #palette='pastel',
                )

ax.set(title = 'Length of biblical books')
ax.tick_params(labelrotation=90)

# %% [markdown]
# ## Which are the most frequently occurring lexemes in the MT: barplot.

# %%
lex_counts = mt.lex2.value_counts()[:100]

# %%
ax = sns.barplot(x=lex_counts.index, 
                 y=lex_counts, 
                 #hue=word_counts.index,
                 #palette='pastel',
                )

ax.set(title = 'Lexeme frequencies in the MT')
ax.tick_params(labelrotation=90)

# %% [markdown]
# ## Distribution of אלהים and יהוה in Leviticus: stripchart.

# %% [markdown]
# How are אלהים and יהוה  distributed in the book of Leviticus?

# %%
god = mt[mt.lex2.isin(['>LHJM/', 'JHWH/'])]
god_in_lev = god[god.S1 == 'Leviticus']

# %%
god_in_lev.shape
# Out:
# (364, 19)

# %%
god_in_lev.head()
# Out:
#            R         S1  S2  S3   NODE1   TYPE1  \
# 52518  52519  Leviticus   1   1  437873  clause
# 52538  52539  Leviticus   1   2  437878  clause
# 52571  52572  Leviticus   1   3  437883  clause
# 52593  52594  Leviticus   1   5  437887  clause
# 52691  52692  Leviticus   1   9  437901  clause
#
#                                                    TEXT1  NODE2 TYPE2  \
# 52518      וַיְדַבֵּ֤ר יְהוָה֙ אֵלָ֔יו מֵאֹ֥הֶל מֹועֵ֖ד   52519  word
# 52538       כִּֽי־יַקְרִ֥יב מִכֶּ֛ם קָרְבָּ֖ן לַֽיהוָ֑ה   52539  word
# 52571  אֶל־פֶּ֝תַח אֹ֤הֶל מֹועֵד֙ יַקְרִ֣יב אֹתֹ֔ו לִ...  52572  word
# 52593    וְשָׁחַ֛ט אֶת־בֶּ֥ן הַבָּקָ֖ר לִפְנֵ֣י יְהוָ֑ה   52594  word
# 52691            אִשֵּׁ֥ה רֵֽיחַ־נִיחֹ֖וחַ לַֽיהוָֽה׃ ס   52692  word
#
#             TEXT2 g_cons2 gn2 language2   lex2 nu2  ps2   sp2  vs2  vt2
# 52518    יְהוָה֙     JHWH   m    Hebrew  JHWH/  sg  NaN  nmpr  NaN  NaN
# 52538     יהוָ֑ה     JHWH   m    Hebrew  JHWH/  sg  NaN  nmpr  NaN  NaN
# 52571   יְהוָֽה׃     JHWH   m    Hebrew  JHWH/  sg  NaN  nmpr  NaN  NaN
# 52593    יְהוָ֑ה     JHWH   m    Hebrew  JHWH/  sg  NaN  nmpr  NaN  NaN
# 52691  יהוָֽה׃ ס     JHWH   m    Hebrew  JHWH/  sg  NaN  nmpr  NaN  NaN

# %%
ax = sns.stripplot(y='S2',
                   x='lex2',
                   data=god_in_lev, 
                   hue='lex2',
                   palette='Set1',
                   alpha=.5,
                   size=5
                   ).set(title='"JHWH" and "God" in MT Leviticus')

# %%
god_in_lev.lex2.value_counts()
# Out:
# lex2
# JHWH/     311
# >LHJM/     53
# Name: count, dtype: int64

# %% [markdown]
# ## Which book has the longest average clause length?

# %%
mt.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis   1   1  427559  clause
# 1  2  Genesis   1   1  427559  clause
# 2  3  Genesis   1   1  427559  clause
# 3  4  Genesis   1   1  427559  clause
# 4  5  Genesis   1   1  427559  clause
#
#                                                TEXT1  NODE2 TYPE2       TEXT2  \
# 0  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...      1  word         בְּ
# 1  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...      2  word  רֵאשִׁ֖ית
# 2  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...      3  word    בָּרָ֣א
# 3  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...      4  word  אֱלֹהִ֑ים
# 4  בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖י...      5  word       אֵ֥ת
#
#   g_cons2  gn2 language2    lex2  nu2  ps2   sp2  vs2   vt2
# 0       B  NaN    Hebrew       B  NaN  NaN  prep  NaN   NaN
# 1   R>CJT    f    Hebrew  R>CJT/   sg  NaN  subs  NaN   NaN
# 2     BR>    m    Hebrew    BR>[   sg   p3  verb  qal  perf
# 3   >LHJM    m    Hebrew  >LHJM/   pl  NaN  subs  NaN   NaN
# 4      >T  NaN    Hebrew      >T  NaN  NaN  prep  NaN   NaN

# %%
gen = mt[mt.S1 == 'Genesis']

# %%
gen.NODE1.value_counts().mean()
# Out:
# np.float64(4.8044095540337395)

# %%
mean_lengths = []

all_books = mt.S1.unique()

for book in all_books:
    book_df = mt[mt.S1 == book]
    mean_len = book_df.NODE1.value_counts().mean()
    mean_lengths.append(mean_len)

# %%
ax = sns.barplot(x=list(all_books), 
                 y=mean_lengths, 
                 #hue=word_counts.index,
                 #palette='pastel',
                )

ax.set(title = 'Average length of clauses of books in the MT')
ax.tick_params(labelrotation=90)

# %% [markdown]
# ## Distribution of parts of speech in biblical books: Heatmap with cluster analysis.

# %%
mt_heb = mt[mt.language2 == 'Hebrew']

pos_df = pd.crosstab(mt_heb.S1, mt_heb.sp2)

# %%
standardized_pos_df = pos_df.div(pos_df.sum(axis=1), axis=0)
# Out:
# S1
# Genesis          1.0
# Exodus           1.0
# Leviticus        1.0
# Numbers          1.0
# Deuteronomy      1.0
# Joshua           1.0
# Judges           1.0
# 1_Samuel         1.0
# 2_Samuel         1.0
# 1_Kings          1.0
# 2_Kings          1.0
# Isaiah           1.0
# Jeremiah         1.0
# Ezekiel          1.0
# Hosea            1.0
# Joel             1.0
# Amos             1.0
# Obadiah          1.0
# Jonah            1.0
# Micah            1.0
# Nahum            1.0
# Habakkuk         1.0
# Zephaniah        1.0
# Haggai           1.0
# Zechariah        1.0
# Malachi          1.0
# Psalms           1.0
# Job              1.0
# Proverbs         1.0
# Ruth             1.0
# Song_of_songs    1.0
# Ecclesiastes     1.0
# Lamentations     1.0
# Esther           1.0
# Daniel           1.0
# Ezra             1.0
# Nehemiah         1.0
# 1_Chronicles     1.0
# 2_Chronicles     1.0
# dtype: float64

# %%
g = sns.clustermap(standardized_pos_df, 
                   center=0, 
                   cmap="vlag",
                   dendrogram_ratio=(.1, .2),
                   cbar_pos=(.02, .32, .03, .2),
                   linewidths=.75, figsize=(12, 13))
